# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Azham-Oman/AI_Portfolio/blob/main/bing_image_downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install bing-image-downloader

# %%
from bing_image_downloader import downloader
downloader.download("dog", limit=100)
# Out:
# [%] Downloading Images to /content/dataset/dog
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 120 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://images.ctfassets.net/m5ehn3s5t7ec/wp-image-197645/ebb53a9acfebebaf0b7cdfd540ff6040/Jack-Russell-Terrier-Dog-Breed-Information.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://wagbrag.com/wp-content/uploads/2016/04/dog-1194077_1280.jpg
# [!] Issue getting: https://wagbrag.com/wp-content/uploads/2016/04/dog-1194077_1280.jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #2 from https://media.npr.org/assets/img/2019/11/08/dog_wide-b1e7df85bc41928fd4b9b0278742f6793fe5e403.jpg?s=1400&amp;c=100&amp;f=jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://weknowyourdreams.com/images/dog/dog-06.jpg
# [Error]Invalid image, not saving http://weknowyourdreams.com/images/dog/dog-06.jpg
#
# [!] Issue getting: http://weknowyourdreams.com/images/dog/dog-06.jpg
# ...
