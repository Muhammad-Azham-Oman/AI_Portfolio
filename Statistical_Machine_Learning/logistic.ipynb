# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Azham-Oman/AI_Portfolio/blob/main/logistic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics import confusion_matrix, classification_report
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv("/content/Heart_disease_statlog.csv")
df = pd.DataFrame(data)

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     70    1   3       130   322    0        2      109      0      2.4
# 1     67    0   2       115   564    0        2      160      0      1.6
# 2     57    1   1       124   261    0        0      141      0      0.3
# 3     64    1   3       128   263    0        0      105      1      0.2
# 4     74    0   1       120   269    0        2      121      1      0.2
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 265   52    1   2       172   199    1        0      162      0      0.5
# 266   44    1   1       120   263    0        0      173      0      0.0
# 267   56    0   1       140   294    0        2      153      0      1.3
# 268   57    1   3       140   192    0        0      148      0      0.4
# 269   67    1   3       160   286    0        2      108      1      1.5
#
#      slope  ca  thal  target
# 0        1   3     1       1
# 1        1   0     3       0
# ...

# %%
data = data.drop(columns=['sex'])

# %%
data
# Out:
#      age  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0     70   3       130   322    0        2      109      0      2.4      1
# 1     67   2       115   564    0        2      160      0      1.6      1
# 2     57   1       124   261    0        0      141      0      0.3      0
# 3     64   3       128   263    0        0      105      1      0.2      1
# 4     74   1       120   269    0        2      121      1      0.2      0
# ..   ...  ..       ...   ...  ...      ...      ...    ...      ...    ...
# 265   52   2       172   199    1        0      162      0      0.5      0
# 266   44   1       120   263    0        0      173      0      0.0      0
# 267   56   1       140   294    0        2      153      0      1.3      1
# 268   57   3       140   192    0        0      148      0      0.4      1
# 269   67   3       160   286    0        2      108      1      1.5      1
#
#      ca  thal  target
# 0     3     1       1
# ...

# %%
X = data.drop(columns=['target'])
Y = data['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=20 )

# %%
model = LogisticRegression()

# %%
model = model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
y_pred = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.8148148148148148

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.81        25
#            1       0.88      0.76      0.81        29
#
#     accuracy                           0.81        54
#    macro avg       0.82      0.82      0.81        54
# weighted avg       0.82      0.81      0.81        54

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[22,  3],
#        [ 7, 22]])
