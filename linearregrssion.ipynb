# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Azham-Oman/AI_Portfolio/blob/main/linearregrssion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
np.random.seed(0)

studied_hours = (np.random.normal(4.0,7.0,100)).astype(int)

exam_score = (studied_hours + 50 + np.random.uniform(5,10, 100)).astype(int)

# %%
data = pd.DataFrame({"Studied_hours": studied_hours, "Exam_Score": exam_score,})
print(data)
# Out:
#     Studied_hours  Exam_Score
# 0              16          73
# 1               6          64
# 2              10          65
# 3              19          75
# 4              17          75
# ..            ...         ...
# 95              8          67
# 96              4          62
# 97             16          75
# 98              4          60
# 99              6          64
#
# [100 rows x 2 columns]

# %%
X = data[["Studied_hours"]]
Y = data["Exam_Score"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=5)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
data2 = pd.DataFrame({"y_pred": y_pred, "Y_test": y_test})
data2
# Out:
#        y_pred  Y_test
# 66  49.748209      49
# 32  54.819100      57
# 46  52.790744      53
# 28  71.045953      69
# 74  62.932527      61
# 23  55.833279      58
# 10  61.918349      62
# 20  43.663139      46
# 17  58.875814      58
# 35  61.918349      60
# 97  73.074310      75
# 37  69.017597      69
# 70  65.975062      67
# 40  53.804922      56
# 60  56.847457      59
# 34  57.861635      58
# 42  49.748209      48
# 57  62.932527      64
# 12  65.975062      66
# 69  60.904170      63

# %%
model.score(X_test, y_test)
# Out:
# 0.9516967118591414

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print(f"mse is {mse}")
print(f"r2 is {r2}")
# Out:
# mse is 2.535439594513666
# r2 is 0.9516967118591414

# %%
import joblib

# %%
joblib.dump(model,'model.pkl')
# Out:
# ['model.pkl']

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test,y_pred,color='red')
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-1979373558.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
